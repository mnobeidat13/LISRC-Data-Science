# %% [markdown]
# In this assignemt you will build a feed forward model to predict the object the image <br>
# Check
# > [https://www.kaggle.com/code/mohammedobeidat/mnist-digits-classification/notebook?scriptVersionId=142326914](http://)
# >
# for refrence

# %% [markdown]
# # Imports

# %%
from tensorflow import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Load dataset

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
print(x_train.shape) 
print(y_train.shape)
print(x_test.shape) 
print(y_test.shape)
x_train[0].shape
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)
# (32, 32, 3)

# %%
for i in range(10):
    num = np.random.randint(1,40000,1)[0]
    plt.figure(10,figsize=(12,15))
    plt.subplot(6,5,i+1)
    plt.imshow(x_train[num,:,:],cmap='gray')
    plt.axis('off')

# %% [markdown]
# # Scaling

# %% [markdown]
# # Model Building

# %%
batch_size = 32
epochs = 5
learning_rate = 0.01

# %%
loss_func = keras.losses.SparseCategoricalCrossentropy(from_logits=True) # produces a aprobabilty between 0 and 1

optimizer = keras.optimizers.SGD(learning_rate = learning_rate)

model.compile(optimizer = optimizer, loss = loss_func, metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 loss_func = keras.losses.SparseCategoricalCrossentropy(from_logits=True) # produces a aprobabilty between 0 and 1
#       3 optimizer = keras.optimizers.SGD(learning_rate = learning_rate)
# ----> 5 model.compile(optimizer = optimizer, loss = loss_func, metrics=['accuracy'])
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Model Training

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(5, 3))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# plt.ylim(0, 1)
plt.grid(True)
plt.show()

# %%
[test_loss , test_accuracy] = model.evaluate(x_test,y_test)
print('Test Accuracy: ',test_accuracy)
print("Test loss:",test_loss)

# %% [markdown]
# # Predictions

# %%
class_labels = {
    1: 'airplane',
    2: 'automobile',
    3: 'bird',
    4: 'cat',
    5: 'deer',
    6: 'dog',
    7: 'frog',
    8: 'horse',
    9: 'ship',
    10: 'truck'
}

# %%
sample_size = 10  # Number of samples to plot
sample_indices = np.random.choice(len(x_test), size=sample_size, replace=False)
sample_images = x_test[sample_indices]
sample_labels = y_test[sample_indices]
predictions = model.predict(sample_images)
predicted_labels = np.argmax(predictions, axis=1)

# Plot the sample images with their predicted labels
plt.figure(figsize=(12, 6))
for i in range(sample_size):
    plt.subplot(2, 5, i + 1)
    plt.imshow(sample_images[i], cmap='gray')
    plt.title(f'Predicted: {class_labels[predicted_labels[i]]}\nActual: {class_labels[sample_labels[i]]}')
    plt.axis('off')

plt.tight_layout()
plt.show()
